# %%
import json

class Restaurant :
    def __init__(self):
        self.foods={}
        self.food_id=len(self.foods)
        self.user={}
        self.user_id=len(self.user)
        self.list=[]
        
    def food_items(self):
        self.name=input("Enter the name of the food :")
        self.quantity=input("Enter the quantity in ml,gm,kg,pieces...:")
        self.price=input("Enter price in rs :")
        self.discount=input("Enter the discount in rs : ")
        self.stock=input("enter how many in stock in ml,kg,gm,pieces..: ")
        self.items={"name":self.name,"quantity":self.quantity,"price":self.price,"discount":self.discount,"stocks":self.stock}
        self.food_id=len(self.foods)+1
        self.foods[self.food_id]=self.items
        print(self.foods)
        with open("Food_items.json","w") as f :
            json.dump(self.foods,f)
        print("item added successfully ...............")
    
    def user_info(self):
        print("********** Welcome to the user section , please registor user self**********")
        self.name=input("Enter your name  :")
        self.M_no=input("Enter your Mobile number:")
        self.email=input("Enter your E-mail :")
        self.Address=input("Enter your Address : ")
        self.pas=input("enter your password : ")
        self.user_in={"name":self.name,"Mobile number":self.M_no,"E-Mail":self.email,"Address":self.Address,"password":self.pas}
        self.user_id=len(self.user)+1
        self.user[self.user_id]=self.user_in
        print("your profile with user_id at front :",self.user)
        with open("user.json","w") as f :
            json.dump(self.user,f)
        print(" successfully Registored ...............")
        
    def remove_items(self):
        del self.foods[int(input("enter the food_id to delete the item :"))]
        with open("Food_items.json","w") as f :
            json.dump(self.foods,f)
        print("remaning items are :",self.foods)
        
    def edit_food_item(self):
        f_id=int(input("Enter the food_id which wants to update"))
        print("The list of food in this food_id is :",self.foods[f_id])
        for i in self.foods[f_id]:
            self.foods[f_id][i]=input(f"Enetr the {i} that you wants to update")
        with open("Food_items.json","w") as f :
            json.dump(self.foods,f)
        print(self.foods)
    
    def update_profile(self):
        self.array={}
        u_id=input("enter the user _id to edit")
        with open("user.json","r")as f:
            x=json.load(f)
        for k,v in x.items():
            if k==u_id:
                print(v)
                for m,n in v.items():
                    for i in range(len(v.items())):
                        self.array[m]=input(f"enter {m} to updated one :")
                        break
                self.user[u_id]=self.array    
                        
                with open("user.json","w") as f :
                    json.dump(self.user,f)
            else :
                print("wrong user_id")
    def order(self):
        if self.list == []:
            print("Sorry no order given till now ")
            return
        print(self.list)
    def menu(self):
        while True :
            
            print("*************** menu avalable here ****************")
            print("1. Tandoori Chicken (4 pieces) [INR 240]")
            print("2. Vegan Burger (1 Piece) [INR 320]")
            print("3. Truffle Cake (500gm) [INR 900]")
            print("4. Exit")
            
            e = list(map(int,input("Enter your choice: ").split())) 
            for i in range(len(e)):
                print(e[i])
                if e[i]==1:
                    self.list.append(" Tandoori chicken (4 pieces) [INR 240]")
                    print(self.list)
                    
                elif e[i]==2:
                    self.list.append(" Vegan Burger (1 Piece) [INR 320] ")
                    print(self.list)
                    
                elif e[i]==3:
                    self.list.append(" Truffle cake (500gm) [INR 900]")
                    print(self.list)
                    
                elif e[i]==4:
                    print("thanks for order")
                    return
                else :
                    print("Wrong choice")
                
                    
       
    def view_food_items(self):
        print("List of all food items")
        with open("Food_items.json","r")as f:
            x = json.load(f)
            for k,v in x.items():
                print(k,v)
    
    def remove_order(self):
        if self.list == []:
            print("Sorry no order given till now ")
            return
        print("The Order are :",self.list)
        self.order_no=int(input("Enter the index no(1,2,..) to remove your order:"))
        del self.list[self.order_no-1]
        print("The present order list is ",self.list)
        
    def look_at_user(self):
        u_id=input("enter the user _id to edit")
        with open("user.json","r")as f:
            x=json.load(f)
        for k,v in x.items():
            if k==u_id:
                print(v)
r=Restaurant()

def admin():
    
    admin_id=input("Enter your user name :")
    admin_pass=input("Enter the password :")
    while True:
        if admin_id=="F5@admin" and admin_pass=="123456" :
            print(".............welcome to Admin Area........")
            print("Choose the functions you wants to add in manu ..:")
            print("a.For Adding new good items .")
            print("b.For view food list .")
            print("c.remove items from list .")
            print("d.Edit the food items .")
            print("e.exit ")
            j=input("enter your choice :")
            if j=='a':
                r.food_items()
            elif j=='b':
                r.view_food_items()
            elif j=='c':
                r.remove_items()
            elif j=='d' :
                r.edit_food_item()
            elif j=='e':
                break
            else :
                print("wrong choice")
def user_order():
    while True:
        print("***************WELCOME TO USER SECTION **************")
        print("a. For see your profile")
        print("b. For update your profile")
        print("c. For New Order ")
        print("d. For see the Order History")
        print("e. Removed the Order from the list ")
        print("f. For exit")
        useroption=input("Enter your choice :")
        if useroption=='a':
            r.look_at_user()
        elif useroption=='b':
            r.update_profile()
        elif useroption == 'c':
            r.menu()
        elif useroption == 'd':
            r.order()
        elif useroption =='e':
            r.remove_order()
        elif useroption =='f':
            break
        else :
            print("wrong choice")
        
def user():
    while True:
        print("******* WELCOME TO USER AREA *********")
        print("a. Register your self ,For new user(don't have a user_id and password)")
        print("b. Log in For old user(have a user_id and password)")
        print("c. Exit")
        l=input("\nEnter your choice :")
        if l=='a':
            r.user_info()
        elif l=='b':
            user_id=input("enter your email:")
            password=input("enter your password :")
            with open("user.json","r")as f:
                x=json.load(f)
                for k,v in x.items():
                    for j in v.values():
                        if j == user_id:
                            for j in v.values():
                                if j == password :
                                    user_order()
                                    break
        elif l=='c':
            break
        else:
            print("wrong choice")
                                    
                            
                                            
while True :
    print("\t\t..............WELCOME TO THE F5 DEVELOPERS RESTAURANT.............\t\t\n\n")
    print("1.For Admin ")
    print("2.For User")
    print("0 For Exit")
    i=int(input("enter your choice :"))
    if i==0 :
        print("thanks for visit ")
        break
    elif i==1:
        admin()
    elif i==2:
        user()
    else :
        print("wrong choice ")
# Out:
# 		..............WELCOME TO THE F5 DEVELOPERS RESTAURANT.............
#
#
# 1.For Admin
# 2.For User
# 0 For Exit
# enter your choice :1
# Enter your user name :F5@admin
# Enter the password :123456
# .............welcome to Admin Area........
# Choose the functions you wants to add in manu ..:
# a.For Adding new good items .
# b.For view food list .
# c.remove items from list .
# d.Edit the food items .
# e.exit
# enter your choice :a
# Enter the name of the food :roll
# Enter the quantity in ml,gm,kg,pieces...:13
# Enter price in rs :70
# Enter the discount in rs : 0
# enter how many in stock in ml,kg,gm,pieces..: 123
# {1: {'name': 'roll', 'quantity': '13', 'price': '70', 'discount': '0', 'stocks': '123'}}
# item added successfully ...............
# .............welcome to Admin Area........
# Choose the functions you wants to add in manu ..:
# a.For Adding new good items .
# b.For view food list .
# c.remove items from list .
# d.Edit the food items .
# e.exit
# ...

# %% [markdown]
# ##
